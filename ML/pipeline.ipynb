# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk

# %%
def openFile(path):
    df = pd.read_csv(path ,header=0, encoding='utf-8')
    return df

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import cross_validate


def get_classifier_cv_score(model, X, y, scoring='accuracy', cv=7):
    results = cross_validate(model, X, y, cv=cv,scoring=scoring,return_train_score=Tru)
    return [results['train_score'].mean(), results['test_score'].mean()]

# %%
def print_grid_search_result(grid_search):
    print(grid_search.best_params_)
    print("training score= {:.3f}; validation score={:.3f}".format(grid_search.cv_results_['mean_train_score'][grid_search.best_index_],
                                                                  grid_search.cv_results_['mean_test_score'][grid_search.best_index_]))

# %%
def getCorpus(df):
    corpus = df['processed_sentence'].iloc[:].values
    return corpus

# %%
def wordVector(corpus):
    word_bag = CountVectorizer().fit_transform(corpus)
    return word_bag

# %%
def splitData(word_bag, df):
    return train_test_split(word_bag, df['Sentiment'],test_size = 0.3, random_state=42)

# %%
def algoSelection(word_bag, df, X_train, X_test, y_train, y_test):
    models = [RandomForestClassifier(random_state=42, max_depth=5), LogisticRegression(random_state=42), GradientBoostingClassifier(random_state=42), BernoulliNB()]
    for model in models:
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        print(model)
        print("Training score: {0:.3f}".format(model.score(X_train,y_train)))
        print("Test score: {0:.3f}".format(model.score(X_test,y_test)))
        print(classification_report(y_test,y_pred))
        print()

# %%
from sklearn.model_selection import GridSearchCV
def gridSearchLogReg(word_bag, df, X_train, y_train):
    
    solvers = ['newton-cg', 'lbfgs', 'liblinear']
    penalty = ['l2']
    c_values = [100, 10, 1.0, 0.1, 0.01]
    grid = dict(solver=solvers,penalty=penalty,C=c_values)
    
    clf = GridSearchCV(LogisticRegression(random_state=42), param_grid=grid, scoring="f1_macro", cv=7, return_train_score=True)
    clf.fit(X_train, y_train)
    print_grid_search_result(clf)

# %%
df= openFile('../labeling/raw_labeled_500_notickers.csv')

# %%
df
# Out:
#      Unnamed: 0 Sentiment                                 processed_sentence
# 0             0       Buy                    long dollarsign twtr dollarsign
# 1             1      Hold  sneak peek minussign tomorrow follow minussign...
# 2             2      Hold                        dollarsign cook taking home
# 3             3       Buy                                               long
# 4             4      Hold  also minussign normally buy type stuff online ...
# ..          ...       ...                                                ...
# 517         517      Hold                                  advice bagholders
# 518         518      Sell                  minussign numberplaceholder share
# 519         519       Buy                                               call
# 520         520       Buy                                          used call
# 521         521       Buy                                    dollarsign call
#
# [522 rows x 3 columns]

# %%
word_bag = wordVector(getCorpus(df))

# %% [markdown]
# <font size="25">Bag-of-Words

# %%
X_train, X_test, y_train, y_test= splitData(word_bag, df)
scores = algoSelection(word_bag, df, X_train, X_test, y_train, y_test)
print(scores)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)
# Training score: 0.704
# Test score: 0.707
#               precision    recall  f1-score   support
#
#          Buy       0.64      1.00      0.78        73
#         Hold       1.00      0.30      0.46        47
#         Sell       0.83      0.65      0.73        37
#
#     accuracy                           0.71       157
#    macro avg       0.82      0.65      0.66       157
# weighted avg       0.79      0.71      0.67       157
#
#
# LogisticRegression(random_state=42)
# Training score: 0.951
# Test score: 0.854
#               precision    recall  f1-score   support
#
#          Buy       0.89      0.93      0.91        73
#         Hold       0.94      0.66      0.78        47
#         Sell       0.73      0.95      0.82        37
#
#     accuracy                           0.85       157
#    macro avg       0.85      0.85      0.84       157
# weighted avg       0.87      0.85      0.85       157
#
#
# GradientBoostingClassifier(random_state=42)
# Training score: 0.981
# Test score: 0.854
#               precision    recall  f1-score   support
#
#          Buy       0.88      0.99      0.93        73
#         Hold       0.94      0.64      0.76        47
#         Sell       0.74      0.86      0.80        37
#
#     accuracy                           0.85       157
#    macro avg       0.85      0.83      0.83       157
# weighted avg       0.86      0.85      0.85       157
#
#
# BernoulliNB()
# Training score: 0.729
# Test score: 0.688
#               precision    recall  f1-score   support
#
#          Buy       0.62      0.99      0.76        73
#         Hold       1.00      0.36      0.53        47
#         Sell       0.83      0.51      0.63        37
#
#     accuracy                           0.69       157
#    macro avg       0.81      0.62      0.64       157
# weighted avg       0.78      0.69      0.66       157
#
#
# None

# %%
gridSearchLogReg(word_bag, df)

# %% [markdown]
# <font size="25"> TF-IDF</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(df['processed_sentence'], df['Sentiment'],test_size = 0.3, random_state=42)

# %%
tfidf_vectorizer = TfidfVectorizer() 
tfidf_train_vectors = tfidf_vectorizer.fit_transform(X_train)
tfidf_test_vectors = tfidf_vectorizer.transform(X_test)

# %%
scores = algoSelection(word_bag, df, tfidf_train_vectors, tfidf_test_vectors, y_train, y_test)
print(scores)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)
# Training score: 0.668
# Test score: 0.650
#               precision    recall  f1-score   support
#
#          Buy       0.61      0.97      0.75        73
#         Hold       1.00      0.26      0.41        47
#         Sell       0.66      0.51      0.58        37
#
#     accuracy                           0.65       157
#    macro avg       0.76      0.58      0.58       157
# weighted avg       0.74      0.65      0.61       157
#
#
# LogisticRegression(random_state=42)
# Training score: 0.937
# Test score: 0.860
#               precision    recall  f1-score   support
#
#          Buy       0.94      0.92      0.93        73
#         Hold       0.89      0.72      0.80        47
#         Sell       0.71      0.92      0.80        37
#
#     accuracy                           0.86       157
#    macro avg       0.85      0.85      0.84       157
# weighted avg       0.87      0.86      0.86       157
#
#
# GradientBoostingClassifier(random_state=42)
# Training score: 0.995
# Test score: 0.866
#               precision    recall  f1-score   support
#
#          Buy       0.89      0.96      0.92        73
#         Hold       0.97      0.68      0.80        47
#         Sell       0.76      0.92      0.83        37
#
#     accuracy                           0.87       157
#    macro avg       0.87      0.85      0.85       157
# weighted avg       0.88      0.87      0.86       157
#
#
# BernoulliNB()
# Training score: 0.778
# Test score: 0.701
#               precision    recall  f1-score   support
#
#          Buy       0.61      0.99      0.75        73
#         Hold       1.00      0.36      0.53        47
#         Sell       0.95      0.57      0.71        37
#
#     accuracy                           0.70       157
#    macro avg       0.85      0.64      0.67       157
# weighted avg       0.81      0.70      0.68       157
#
#
# None

# %% [markdown]
# <font size="25">N-grams

# %%
bigram_vectorizer = CountVectorizer(ngram_range=(2,2), token_pattern=r'\b\w+\b', min_df=1)
#adjust range to get bi or tri grams
bg = bigram_vectorizer.fit_transform(getCorpus(df))

# %%
bg_features = bigram_vectorizer.get_feature_names()
bg_features
# Out:
# c:\Users\Calgary123\anaconda3\envs\ensf-ml\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['able buy',
#  'acquisition cooperation',
#  'actually call',
#  'adding numberplaceholder',
#  'advice bagholders',
#  'advisor financial',
#  'afraid buy',
#  'ahrendts depart',
#  'aircraft effort',
#  'airline adding',
#  'align business',
#  'almost numberplaceholder',
#  'alphabet earnings',
#  'also looking',
#  'also minussign',
#  'also scared',
#  'always bagholders',
#  'amazon earnings',
#  'amazon michael',
#  'amazon new',
#  'amc moon',
#  'amc mvis',
#  'amc wild',
#  'ameritrade tda',
#  'anaus fucking',
#  'angela ahrendts',
#  'anime gambling',
#  'announce hodling',
#  'announced new',
#  'antitrust regulator',
#  'anyone hodling',
#  'anyone thinking',
#  'anyone want',
#  'anything believe',
#  'apart oil',
#  'ape diamond',
#  'ape gemstoneemoji',
#  'ape like',
#  'appl snappl',
#  'apple ceo',
#  'apple earnings',
#  'appointed chairman',
#  'appointed critic',
#  'approve usd',
#  'april sell',
#  'april year',
#  'arconic engineering',
#  'around dollarsign',
#  'art inc',
#  'as use',
#  'asia pacific',
#  'asset buy',
#  'asshole motherfucker',
#  'associate inc',
#  'attract premium',
#  'audio comment',
#  'authority control',
#  'autists buying',
#  'available according',
#  'awarded large',
#  'away telecom',
#  'axxxxxxxw minussign',
#  'back pocket',
#  'backdoor dilution',
#  'bad boy',
#  'bad buying',
#  'bag holder',
#  'bag holding',
#  'bag minussign',
#  'bagholders lick',
#  'bagholders right',
#  'bagholders yacht',
#  'balance dollarsign',
#  'banana anaus',
#  'bankrupt despite',
#  'basically security',
#  'bear bet',
#  'bear buttholes',
#  'bear case',
#  'bear field',
#  'bear fuck',
#  'bear get',
#  'bear morning',
#  'bear nio',
#  'bear post',
#  'bear put',
#  'bear sell',
#  'bear shorting',
#  'bear summarized',
#  'bear today',
#  'bear tomorrow',
#  'bear weekend',
#  'bear wrong',
#  'bearemoji bear',
#  'bearemoji time',
#  'bearish brk',
#  'bearish dollarsign',
#  'bearish hard',
#  'bearish sentiment',
#  'becky tendies',
#  'behind guidance',
#  'believe would',
#  'believer gemstoneemoji',
#  'benefit decrease',
#  'ber fuk',
#  'bet bear',
#  'bet dollarsign',
#  'birth tesla',
#  'bln expansion',
#  'bln regeneron',
#  'board likely',
#  'book today',
#  'borrow rate',
#  'boston scientific',
#  'bottom day',
#  'bottom minussign',
#  'bought buy',
#  'bought call',
#  'bought put',
#  'boy selling',
#  'break even',
#  'brien replace',
#  'brigade moon',
#  'brrrrr rocketemoji',
#  'brutal sell',
#  'bull bear',
#  'bull case',
#  'bull elon',
#  'bull right',
#  'bullish bearish',
#  'bullish bet',
#  'bullish case',
#  'bullish dollarsign',
#  'bullish hard',
#  'bullish long',
#  'bullrun secured',
#  'bunch asshole',
#  'business three',
#  'buy anything',
#  'buy bagholding',
#  'buy call',
#  'buy dip',
#  'buy dollarsign',
#  'buy first',
#  'buy gemstoneemoji',
#  'buy get',
#  'buy greenland',
#  'buy high',
#  'buy hodl',
#  'buy instead',
#  'buy moron',
#  'buy pls',
#  'buy plussign',
#  'buy put',
#  'buy rumor',
#  'buy save',
#  'buy sell',
#  'buy sftby',
#  'buy spxs',
#  'buy type',
#  'buy undervalued',
#  'buy xilinx',
#  'buyer dollarsign',
#  'buying call',
#  'buying dollarsign',
#  'buying holding',
#  'buying price',
#  'buying put',
#  'buying rocketemoji',
#  'buying selling',
#  'buying tesla',
#  'call also',
#  'call around',
#  'call boy',
#  'call buy',
#  'call daddy',
#  'call debit',
#  'call dollarsign',
#  'call everyone',
#  'call idiot',
#  'call minussign',
#  'call msft',
#  'call nflx',
#  'call nsfw',
#  'call numberplaceholder',
#  'call nvidia',
#  'call option',
#  'call put',
#  'call set',
#  'call spce',
#  'call stock',
#  'call tendies',
#  'call thank',
#  'call took',
#  'call trust',
#  'call win',
#  'call yesterday',
#  'called dollarsign',
#  'capri holding',
#  'card back',
#  'card prediction',
#  'carrying bag',
#  'carrying structural',
#  'case bear',
#  'case perspective',
#  'case wish',
#  'cell tower',
#  'century inc',
#  'ceo tim',
#  'chairman john',
#  'chapter ended',
#  'checking put',
#  'cherry picking',
#  'chief angela',
#  'chief deirdre',
#  'child call',
#  'christmas shopping',
#  'chubb ltd',
#  'class axxxxxxxw',
#  'closed day',
#  'closed minussign',
#  'coal dollarsign',
#  'cognizant technology',
#  'columbian pipeline',
#  'combined price',
#  'company as',
#  'constructionengineering minussign',
#  'continental airline',
#  'continued strength',
#  'contract columbian',
#  'contract petrobras',
#  'contributing dow',
#  'control board',
#  'cook taking',
#  'cooperation expanding',
#  'core ffo',
#  'core ghz',
#  'corp adj',
#  'corp eps',
#  'corp minussign',
#  'course buy',
#  'covering started',
#  'crackhead buying',
#  'crazy gap',
#  'critic amazon',
#  'ctxs plussign',
#  'cummins inc',
#  'current balance',
#  'current level',
#  'currently holding',
#  'currently selling',
#  'daddy satya',
#  'dagger rainbow',
#  'daily tarot',
#  'dated call',
#  'day defeated',
#  'day destroy',
#  'day dollarsign',
#  'day high',
#  'day minussign',
#  'day numberplaceholder',
#  'day relatively',
#  'day together',
#  'daym feel',
#  'dear gemstoneemoji',
#  'debit spread',
#  'decided sell',
#  'decrease underlying',
#  'deep itm',
#  'deez nut',
#  'defeated daily',
#  'definitely looking',
#  'degenerate put',
#  'deirdre brien',
#  'democrat recent',
#  'depart april',
#  'despite liability',
#  'despite numberplaceholder',
#  'destroy end',
#  'diamond fucking',
#  'diamond hand',
#  'different breed',
#  'digital realty',
#  'dilution minussign',
#  'dime call',
#  'dip hodl',
#  'dip minussign',
#  'dip stop',
#  'disclaimer long',
#  'disclaimer retarded',
#  'discovery offshore',
#  'discus minussign',
#  'disney eps',
#  'diversified portfolio',
#  'dividend minussign',
#  'dividend numberplaceholder',
#  'djia apple',
#  'dollar big',
#  'dollarsign alphabet',
#  'dollarsign amazon',
#  'dollarsign announcement',
#  'dollarsign apple',
#  'dollarsign baghodler',
#  'dollarsign bagholder',
#  'dollarsign bear',
#  'dollarsign becky',
#  'dollarsign bet',
#  'dollarsign brigade',
#  'dollarsign brutal',
#  'dollarsign bull',
#  'dollarsign bullrun',
#  'dollarsign buy',
#  'dollarsign call',
#  'dollarsign cook',
#  'dollarsign day',
#  'dollarsign dollarsign',
#  'dollarsign gang',
#  'dollarsign gemstoneemoji',
#  'dollarsign going',
#  'dollarsign gon',
#  'dollarsign grain',
#  'dollarsign hardware',
#  'dollarsign investor',
#  'dollarsign join',
#  'dollarsign keep',
#  'dollarsign last',
#  'dollarsign long',
#  'dollarsign look',
#  'dollarsign march',
#  'dollarsign microsoft',
#  'dollarsign minussign',
#  'dollarsign moon',
#  'dollarsign numberplaceholder',
#  'dollarsign opened',
#  'dollarsign option',
#  'dollarsign put',
#  'dollarsign resulting',
#  'dollarsign rip',
#  'dollarsign rocketemoji',
#  'dollarsign sdc',
#  'dollarsign sell',
#  'dollarsign short',
#  'dollarsign slv',
#  'dollarsign spy',
#  'dollarsign still',
#  'dollarsign terrible',
#  'dollarsign tsla',
#  'dollarsign twtr',
#  'dollarsign unlimited',
#  'dollarsign yolo',
#  'doubling spy',
#  'dow demise',
#  'downgraded capital',
#  'drilling acquisition',
#  'drop minussign',
#  'drop much',
#  'drop previous',
#  'drugged like',
#  'early buy',
#  'early ticker',
#  'earnings call',
#  'earnings thread',
#  'effort attract',
#  'electronic art',
#  'eli lilly',
#  'elon casino',
#  'elon musk',
#  'elon seeing',
#  'emea asia',
#  'end day',
#  'ended april',
#  'ended trade',
#  'engineering appointed',
#  'engineering awarded',
#  'eps adj',
#  'eps eur',
#  'eps minussign',
#  'eps numberplaceholder',
#  'eps usd',
#  'etc one',
#  'eur numberplaceholder',
#  'eurasia drilling',
#  'even maybe',
#  'event dividend',
#  'every dime',
#  'every time',
#  'everyone selling',
#  'execute tomorrow',
#  'expanding russia',
#  'expansion plan',
#  'expectation plain',
#  'exxon mobil',
#  'facetime bug',
#  'fall apart',
#  'favor merging',
#  'feel bad',
#  'feel bagholding',
#  'feel gme',
#  'fellow bag',
#  'ffo eps',
#  'field day',
#  'field offshore',
#  'final dagger',
#  'finally bear',
#  'financial advice',
#  'financial advisor',
#  'fireemoji gemstoneemoji',
#  'first century',
#  'first option',
#  'first put',
#  'fish fuck',
#  'flat minussign',
#  'fluor constructionengineering',
#  'focused engineering',
#  'follow minussign',
#  'following sanction',
#  'fomo caller',
#  'foot locker',
#  'force fish',
#  'former numberplaceholder',
#  'friday january',
#  'friend buy',
#  'fuck bearish',
#  'fuck day',
#  'fuck sell',
#  'fucking company',
#  'fucking hand',
#  'fucking hodl',
#  'fucking retard',
#  'fullmoonfaceemoji rocketemoji',
#  'funding secured',
#  'gambling girl',
#  'gamestop shorted',
#  'gamma squeeze',
#  'gang gemstoneemoji',
#  'gang hodl',
#  'gang stand',
#  'gap hard',
#  'gave strong',
#  'gay bear',
#  'geforce numberplaceholder',
#  'gemstoneemoji gemstoneemoji',
#  'gemstoneemoji gorillaemoji',
#  'gemstoneemoji great',
#  'gemstoneemoji hand',
#  'gemstoneemoji hold',
#  'gemstoneemoji openhandsemoji',
#  'gemstoneemoji palmsuptogetheremoji',
#  'gemstoneemoji raisedbackofhandemoji',
#  'gemstoneemoji raisedhanddarkskintoneemoji',
#  'gemstoneemoji raisedhandemoji',
#  'gemstoneemoji raisinghandsemoji',
#  'gemstoneemoji raisinghandslightskintoneemoji',
#  'gemstoneemoji rocketemoji',
#  'gemstoneemoji wavinghandemoji',
#  'general motor',
#  'geographical region',
#  'get crushed',
#  'get mclaren',
#  'ghz confirmed',
#  'gianaris public',
#  'girl long',
#  'girl went',
#  'gme hodler',
#  'gme hodlers',
#  'gmeusdgamestop corp',
#  'goal buy',
#  'going bankrupt',
#  'going crazy',
#  'going get',
#  'going moon',
#  'going short',
#  'going zero',
#  'gon take',
#  'got early',
#  'got friend',
#  'grain yolo',
#  'grandma liquidize',
#  'gravy train',
#  'great interface',
#  'green anyone',
#  'green dildo',
#  'group announced',
#  'group eps',
#  'guessed right',
#  'guidance continued',
#  'guidance spy',
#  'guy bullish',
#  'guy long',
#  'guy may',
#  'guy used',
#  'guy want',
#  'hadgies hodl',
#  'hand ape',
#  'happens announce',
#  'hard expected',
#  'hard fact',
#  'hard right',
#  'harder bull',
#  'hardware audio',
#  'heavily shorted',
#  'hell call',
#  'help buy',
#  'henry associate',
#  'hey guy',
#  'high sell',
#  'hodl ape',
#  'hodl banana',
#  'hodl call',
#  'hodl dollarsign',
#  'hodl fellow',
#  'hodl going',
#  'hodl line',
#  'hodl saving',
#  'hodl till',
#  'hodled yolo',
#  'hodler time',
#  'hodlering thinkingfaceemoji',
#  'hodlers carrying',
#  'hodlers different',
#  'hodlers going',
#  'hodling dear',
#  'hodling dollarsign',
#  'hodling like',
#  'hodling line',
#  'hodling strong',
#  'hold bag',
#  'hold hold',
#  'hold till',
#  'holder club',
#  'holder rocketemoji',
#  'holder shark',
#  'holder since',
#  'holding bag',
#  'holding dollarsign',
#  'holding gemstoneemoji',
#  'holding ltd',
#  'holding mvis',
#  'holding snap',
#  'house democrat',
#  'however sell',
#  'huge bullish',
#  'humana inc',
#  'husband put',
#  'idea would',
#  'inb bearish',
#  'inc adj',
#  'inc core',
#  'inc eps',
#  'increased quarterly',
#  'increased yesterday',
#  'increasing last',
#  'industrials increased',
#  'innovative product',
#  'instead rocketemoji',
#  'intel dollarsign',
#  'interactive software',
#  'interest borrow',
#  'interface powerful',
#  'investor bagholders',
#  'investor got',
#  'investor lock',
#  'ipo investor',
#  'item usd',
#  'itm call',
#  'january numberplaceholder',
#  'john plant',
#  'join numberplaceholder',
#  'keep discussion',
#  'keep energy',
#  'keep gemstoneemoji',
#  'know dollarsign',
#  'know guy',
#  'know sound',
#  'large contract',
#  'last call',
#  'last summer',
#  'last week',
#  'launch geforce',
#  'leak ryzen',
#  'let gemstoneemoji',
#  'liability win',
#  'lick deez',
#  'like boy',
#  'like stock',
#  'like verizon',
#  'like way',
#  'like wsb',
#  'likely approve',
#  'likely living',
#  'likely short',
#  'lilly eps',
#  'line ape',
#  'line like',
#  'liquidize asset',
#  'living lavish',
#  'lock minussign',
#  'locker trainer',
#  'long boi',
#  'long call',
#  'long dated',
#  'long dollarsign',
#  'long gravy',
#  'long hold',
#  'long inspo',
#  'long share',
#  'long weed',
#  'long yesterday',
#  'longing coal',
#  'look option',
#  'look remind',
#  'looking buyer',
#  'looking combined',
#  'looking microsoft',
#  'lot yolo',
#  'low dollarsign',
#  'low right',
#  'ltd eps',
#  'magnificent green',
#  'maintenance contract',
#  'make mistake',
#  'make money',
#  'mall operator',
#  'many rainbowemoji',
#  'march dollarsign',
#  'market closed',
#  'may know',
#  'maybe slightly',
#  'measly dollarsign',
#  'merging appl',
#  'mero numberplaceholder',
#  'michael gianaris',
#  'microchip eps',
#  'microsoft earnings',
#  'microsoft possibly',
#  'million dollar',
#  'minussign bagger',
#  'minussign bear',
#  'minussign bullshit',
#  'minussign buy',
#  'minussign buyer',
#  'minussign calling',
#  'minussign class',
#  'minussign currently',
#  'minussign dollarsign',
#  'minussign drop',
#  'minussign elon',
#  'minussign ended',
#  'minussign exercising',
#  'minussign first',
#  'minussign focused',
#  'minussign holder',
#  'minussign interactive',
#  'minussign item',
#  'minussign long',
#  'minussign look',
#  'minussign market',
#  'minussign money',
#  'minussign normally',
#  'minussign numberplaceholder',
#  'minussign order',
#  'minussign point',
#  'minussign related',
#  'minussign salt',
#  'minussign sucker',
#  'minussign thank',
#  'minussign tomorrow',
#  'minussign year',
#  'minute minussign',
#  'miss production',
#  'mistake buy',
#  'mobil oil',
#  'money buy',
#  'month eps',
#  'moon fullmoonfaceemoji',
#  'moon gemstoneemoji',
#  'moon monday',
#  'moon newmoonfaceemoji',
#  'moon profit',
#  'moon rocketemoji',
#  'morning measly',
#  'morning receiving',
#  'motor adj',
#  'mrw dip',
#  'msft amd',
#  'msrp nvidia',
#  'much break',
#  'much overvalued',
#  'multi minussign',
#  'musk anime',
#  'musk signal',
#  'named chief',
#  'nasdaq amazon',
#  'nearly minussign',
#  'need one',
#  'new oil',
#  'new york',
#  'newswires arconic',
#  'newswires boston',
#  'newswires capri',
#  'newswires chubb',
#  'newswires cognizant',
#  'newswires cummins',
#  'newswires digital',
#  'newswires djia',
#  'newswires electronic',
#  'newswires eli',
#  'newswires exxon',
#  'newswires fluor',
#  'newswires foot',
#  'newswires general',
#  'newswires henry',
#  'newswires humana',
#  'newswires inc',
#  'newswires industrials',
#  'newswires microchip',
#  'newswires nasdaq',
#  'newswires nutrien',
#  'newswires schlumberger',
#  'newswires skyworks',
#  'newswires spotify',
#  'newswires take',
#  'newswires technipfmc',
#  'newswires toyota',
#  'newswires twenty',
#  'newswires united',
#  'newswires unum',
#  'newswires vertex',
#  'newswires walt',
#  'nio xpev',
#  'normally buy',
#  'north america',
#  'nothing today',
#  'numberplaceholder aircraft',
#  'numberplaceholder bag',
#  'numberplaceholder bought',
#  'numberplaceholder call',
#  'numberplaceholder contributing',
#  'numberplaceholder core',
#  'numberplaceholder ctxs',
#  'numberplaceholder current',
#  'numberplaceholder day',
#  'numberplaceholder dollarsign',
#  'numberplaceholder even',
#  'numberplaceholder friday',
#  'numberplaceholder guessed',
#  'numberplaceholder guidance',
#  'numberplaceholder million',
#  'numberplaceholder minussign',
#  'numberplaceholder minute',
#  'numberplaceholder month',
#  'numberplaceholder numberplaceholder',
#  'numberplaceholder otm',
#  'numberplaceholder per',
#  'numberplaceholder percentsign',
#  'numberplaceholder plussign',
#  'numberplaceholder premium',
#  'numberplaceholder pretty',
#  'numberplaceholder prev',
#  'numberplaceholder price',
#  'numberplaceholder put',
#  'numberplaceholder share',
#  'numberplaceholder target',
#  'numberplaceholder thx',
#  'numberplaceholder year',
#  'nutrien ltd',
#  'nvidia set',
#  'officially downtrendbearmarket',
#  'offshore brazil',
#  'offshore guyana',
#  'oil discovery',
#  'oil eurasia',
#  'oil group',
#  'oil minussign',
#  'one paying',
#  'one point',
#  'one reason',
#  'one short',
#  'online procrastinated',
#  'opened spread',
#  'openhandsemoji gemstoneemoji',
#  'openhandsemoji like',
#  'openhandsemoji moon',
#  'option call',
#  'option dollarsign',
#  'option trader',
#  'option trading',
#  'option volume',
#  'order event',
#  'otm weekly',
#  'overvalued meme',
#  'pacific north',
#  'panic seller',
#  'panicking dollarsign',
#  'paying cell',
#  'peek minussign',
#  'people buying',
#  'people telling',
#  'per share',
#  'percentsign bottom',
#  'percentsign call',
#  'percentsign dollarsign',
#  'percentsign earnings',
#  'percentsign finally',
#  'percentsign fuck',
#  'percentsign interest',
#  'percentsign investor',
#  'percentsign looking',
#  'percentsign loss',
#  'percentsign minussign',
#  'percentsign nothing',
#  'percentsign numberplaceholder',
#  'percentsign plussign',
#  'percentsign position',
#  'percentsign premarket',
#  'percentsign put',
#  'percentsign return',
#  'percentsign stay',
#  'percentsign upside',
#  'percentsign usd',
#  'perhaps short',
#  'petrobras mero',
#  'pharmaceutical inc',
#  'picking numberplaceholder',
#  'pity elon',
#  'plain recover',
#  'plan city',
#  'plant position',
#  'pls help',
#  'plussign call',
#  'plussign dollarsign',
#  'plussign numberplaceholder',
#  'pocket second',
#  'point drop',
#  'poor degenerate',
#  'portfolio put',
#  'position call',
#  'position ceo',
#  'position one',
#  'possibly even',
#  'pov dollarsign',
#  'powerful tool',
#  'prayer moon',
#  'prediction friday',
#  'premarket trading',
#  'premium almost',
#  'premium traveller',
#  'pretty much',
#  'previous day',
#  'price dollarsign',
#  'price minussign',
#  'price skyrocketed',
#  'price target',
#  'prick shorted',
#  'probably going',
#  'procrastinated christmas',
#  'product strategy',
#  'production number',
#  'profit buy',
#  'profit porn',
#  'profit selling',
#  'promised take',
#  'provider like',
#  'public authority',
#  'purchased call',
#  'put amc',
#  'put call',
#  'put csco',
#  'put dollarsign',
#  'put end',
#  'put every',
#  'put everything',
#  'put final',
#  'put gme',
#  'put going',
#  'put harder',
#  'put last',
#  'put minussign',
#  'put month',
#  'put numberplaceholder',
#  'put promised',
#  'put rest',
#  'put shopping',
#  'put shut',
#  'put speculate',
#  'put strategy',
#  'put today',
#  'put week',
#  'quarterly dividend',
#  'rainbow bear',
#  'rainbowemoji bearemoji',
#  'raisedhanddarkskintoneemoji gemstoneemoji',
#  'raisinghandsemoji action',
#  'raisinghandsemoji gemstoneemoji',
#  'raisinghandslightskintoneemoji amc',
#  'raisinghandslightskintoneemoji strong',
#  'rate numberplaceholder',
#  'really behind',
#  'realty trust',
#  'reason hodl',
#  'receiving green',
#  'recent facetime',
#  'recently diversified',
#  'recover magnificent',
#  'regeneron pharmaceutical',
#  'region emea',
#  'regulator said',
#  'related fall',
#  'relatively flat',
#  'remind much',
#  'reorganisation align',
#  'repeat buy',
#  'resulting nearly',
#  'retail chief',
#  'retard bunch',
#  'retard buy',
#  'retarded financial',
#  'right earnings',
#  'right expectation',
#  'rip share',
#  'rocket rocketemoji',
#  'rocketemoji audio',
#  'rocketemoji disclaimer',
#  'rocketemoji dollarsign',
#  'rocketemoji fireemoji',
#  'rocketemoji gemstoneemoji',
#  'rocketemoji gmeusdgamestop',
#  'rocketemoji hold',
#  'rocketemoji minussign',
#  'rocketemoji raisinghandsemoji',
#  'rocketemoji rocketemoji',
#  'rocketemoji spain',
#  'rocketemoji womanastronautemoji',
#  'roku minussign',
#  'roofied grandma',
#  'route moon',
#  'russia still',
#  'russian antitrust',
#  'ryzen numberplaceholder',
#  'said following',
#  'said rainbowemoji',
#  'salt field',
#  'sanction minussign',
#  'satya gon',
#  'save america',
#  'saving edition',
#  'schlumberger russian',
#  'scientific corp',
#  'scrutiny house',
#  'sdc call',
#  'secured buy',
#  'seeing drugged',
#  'seeing lot',
#  'seems bullish',
#  'selfie earnings',
#  'sell break',
#  'sell call',
#  'sell child',
#  'sell dollarsign',
#  'sell keep',
#  'sell low',
#  'sell minussign',
#  'sell morning',
#  'sell put',
#  'sell said',
#  'selling day',
#  'selling dollarsign',
#  'selling doubling',
#  'selling get',
#  'selling moon',
#  'selling moron',
#  'selling msrp',
#  'selling pussy',
#  'selling share',
#  'selling till',
#  'selling uncovered',
#  'senate appointed',
#  'seriously still',
#  'service business',
#  'service provider',
#  'set execute',
#  'set launch',
#  'sftby tcehy',
#  'shall force',
#  'share available',
#  'share cell',
#  'shark tank',
#  'sheer pity',
#  'shopping mall',
#  'shopping year',
#  'short covering',
#  'short dollarsign',
#  'short far',
#  'short increasing',
#  'short put',
#  'short rocketemoji',
#  'short significantly',
#  'short squeeze',
#  'short story',
#  'short today',
#  ...]

# %%
X_train, X_test, y_train, y_test = train_test_split(bg, df['Sentiment'],test_size = 0.3, random_state=42)

# %%
scores = algoSelection(word_bag, df, X_train, X_test, y_train, y_test)
print(scores)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)
# Training score: 0.518
# Test score: 0.529
#               precision    recall  f1-score   support
#
#          Buy       0.50      1.00      0.66        73
#         Hold       1.00      0.09      0.16        47
#         Sell       1.00      0.16      0.28        37
#
#     accuracy                           0.53       157
#    macro avg       0.83      0.42      0.37       157
# weighted avg       0.77      0.53      0.42       157
#
#
# LogisticRegression(random_state=42)
# Training score: 0.959
# Test score: 0.643
#               precision    recall  f1-score   support
#
#          Buy       0.57      0.99      0.72        73
#         Hold       0.92      0.23      0.37        47
#         Sell       1.00      0.49      0.65        37
#
#     accuracy                           0.64       157
#    macro avg       0.83      0.57      0.58       157
# weighted avg       0.77      0.64      0.60       157
#
#
# GradientBoostingClassifier(random_state=42)
# Training score: 0.951
# Test score: 0.643
#               precision    recall  f1-score   support
#
#          Buy       0.57      0.99      0.72        73
#         Hold       0.92      0.23      0.37        47
#         Sell       0.95      0.49      0.64        37
#
#     accuracy                           0.64       157
#    macro avg       0.81      0.57      0.58       157
# weighted avg       0.76      0.64      0.60       157
#
#
# BernoulliNB()
# Training score: 0.605
# Test score: 0.535
#               precision    recall  f1-score   support
#
#          Buy       0.51      1.00      0.67        73
#         Hold       1.00      0.11      0.19        47
#         Sell       0.75      0.16      0.27        37
#
#     accuracy                           0.54       157
#    macro avg       0.75      0.42      0.38       157
# weighted avg       0.71      0.54      0.43       157
#
#
# None
